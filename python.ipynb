# %% [markdown]
# <a href="https://colab.research.google.com/github/Zanoni77/repositorio-python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1** 🥔  🎱  🍒

# %%
ano = "IV"
print (ano, "competição de programação da Start")
# Out:
# IV competição de programação da Start

# %% [markdown]
# #**Aula 2** : 🥚  🪵  🍠

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_dos_dois = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do de Ana são {pontos_ana}")
print(f"Os pontos totais dos dois são {pontos_dos_dois}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do de Ana são 46
# Os pontos totais dos dois são 70

# %% [markdown]
# #**Aula 3**: ✅  🦤  ⏰

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo
figurinhas_extras = int(input("Digite o número de figurinhas extras: "))
figurinhas_extras = figurinhas_extras // (numero_de_amigos + 2)
figurinhas_joao2 = figurinhas_extras * 2


print(f"João recebeu {figurinhas_joao} figurinhas")
print(f"João recebeu {figurinhas_joao2} figurinhas extras")
# Out:
# Digite o total de figurinhas: 100
# Digite o número de amigos: 5
# Digite o número de figurinhas extras: 12
# João recebeu 28 figurinhas
# João recebeu 2 figurinhas extras

# %% [markdown]
# #**Aula 4** 🍆 💦 🔥
#
# ##dia de prova

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# Digite a posição da porta P (0 ou 1): 1
# Digite a posição da porta R (0 ou 1): 0
# B

# %% [markdown]
# #**Aula 5 - Cálculo do IMC**  🦕 😈 🦏

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# Digite seu peso (em kg): 60
# Digite sua altura (em metros): 1.75
#
# Seu IMC é: 19.59
# Você está no peso ideal.

# %% [markdown]
# #***Aula 6 tabuada*** ⏰ ⚓ ⚾

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# #**Aula 7**  🦓  👺  🦬

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
  idade_filho3 = idade_monica - idade_filho1 - idade_filho2
  idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)
  return idade_filho3, idade_maxima

# %% [markdown]
# #**Aula 8**  🛬  🇩  🔒

# %%
print("Sou seu assistente virtual \n")
nome = input("Digite seu nome: ")
print(f"Olá{nome}, em que posso ajudar?")
print("Qual assunto você deseja tratar: Matemática, Python ou Javascript")
# Out:
# Sou seu assistente virtual
#
# Digite seu nome: Gustavo
# OláGustavo , em que posso ajudar?
# Qual assunto você deseja tratar: Matemática, Python ou Javascript

# %% [markdown]
# #**Aula 9**  ✈  ✅  🍌

# %%
import random
dica = [
"O sucesso começa no momento em que você decide tentar! 💪",
"Nunca é tarde para começar a ser quem você deveria ter sido. ⏳",
"Acredite em si mesmo e todo o resto virá. 🌟",
"Desafios são o combustível para a sua evolução. 🚀",
"Quando você acredita, o impossível se torna possível. ✨",
"A jornada é tão importante quanto o destino. 🌍",
"Grandes coisas nunca vêm de zonas de conforto. 💥",
"O único limite é o que você acredita ser seu limite. 🚧",
"A persistência é o caminho para a realização. 🔑",
"Cada pequeno passo te leva mais perto do seu sonho. 👣",
]
while True:
  pedido = input ("Digite 'dica'  para recebe uma dica ou 'sair' para encerrar").lower()
  if pedido == "dica":
   dica = random.choice(dica)
   print (f"Dica: {dica}")
  elif pedido == "sair":
    print("Até mais")
    break
  else:
    print("Comando não reconhecido. Tente novamente")
# Out:
# Digite 'dica'  para recebe uma dica ou 'sair' para encerrardica
# Dica: Grandes coisas nunca vêm de zonas de conforto. 💥
# Digite 'dica'  para recebe uma dica ou 'sair' para encerrarsair
# Até mais
