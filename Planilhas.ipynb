# %% [markdown]
# <a href="https://colab.research.google.com/github/Zanoni77/repositorio-python/blob/main/Planilhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ✈**Sua experiencia atrabalhando em equipe**  🧠

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSCH1pLDfqgHMwhRmbQBdvnBeWy4jCaWNyLzyeMyElnLLiUOX0V3xFI02sC0BNqXKC6tid_6n97ePQG/pub?gid=2045678093&single=true&output=csv")
